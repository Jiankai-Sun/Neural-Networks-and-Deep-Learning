# %%
"""
overfitting
~~~~~~~~~~~
Plot graphs to illustrate the problem of overfitting.
"""

# Standard library
import json
import random
import sys

# My library
sys.path.append('../src/')
import mnist_loader
import network2

# Third-party libraries
import matplotlib.pyplot as plt
import numpy as np

def main(filename, num_epochs, training_cost_xmin = 200,
         test_accuracy_xmin = 200,
         test_cost_xmin = 0,
         training_accuracy_xmin = 0,
         training_set_size = 1000,
         lmbd = 0.0):
    """
    "filename" is the name of the file where the results will be
    stored.  "num_epochs" is the number of epochs to train for.
    "training_set_size" is the number of images to train on.
    "lmbda" is the regularization parameter.  The other parameters
    set the epochs at which to start plotting on the x axis.
    """
    run_network(filename, num_epochs, training_set_size, lmbda)
    make_plots(filename, num_epochs, test_accuracy_xmin, training_cost_xmin, test_accuracy_xmin,
              training_accuracy_xmin, training_set_size)

def run_network(filename, num_epochs, training_set_size = 1000, lmbda = 0.0):
    """
    Train the network for "num_epochs" on "training_set_size"
    images, and store the results in "filename".  Those results can
    later be used by "make_plots".  Note that the results are stored
    to disk in large part because it's convenient not to have to
    "run_network" each time we want to make a plot (it's slow).
    """
    # Make results more easily reproducible
    random.seed(12345678)
    np.random.seed(12345678)
    training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
    net = network2.Network([784, 30, 10], cost = network2.CrossEntropyCost())
    net.large_weight_initializer()
    test_cost, test_accuracy, training_cost, training_accuracy \
        =net.SGD(training_data[:training_set_size], num_epochs, 10, 0.5,
                evaluation_data = test_data, lmbda = lmbda,
                monitor_evaluation_cost = True,
                monitor_evaluation_accuracy = True,
                monitor_training_cost = True,
                monitor_training_accuracy = True)

    f = open(filename, "w")
    json.dump([test_cost, test_accuracy, training_cost, training_accuracy], f)
    f.close()

def make_plots(filename, num_epochs, training_cost_xmin = 200, test_accuracy_xmin = 200,
                test_cost_xmin = 0, training_accuracy_xmin = 0, training_set_size = 1000):
    """
    Load the results from "filename", and generate the corresponding
    plots.
    """
    f = open(filename, "r")
    test_cost, test_accuracy, training_cost, training_accuracy = json.load(f)
    f.close()
    plot_training_cost(training_cost, num_epochs, training_accuracy_xmin)
    plot_test_accuracy(test_accuracy, num_epochs, test_accuracy_xmin)
    plot_test_cost(test_cost, num_epochs, test_cost_xmin)
    plot_training_accuracy(training_accuracy, num_epochs, training_accuracy_xmin, training_set_size)
    plot_overlay(test_accuracy, training_accuracy, num_epochs, min(test_accuracy_xmin, training_accuracy_xmin), training_set_size)

def plot_training_cost(training_cost, num_epochs, training_cost_xmin):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(np.arange(training_cost_xmin, num_epochs),
            training_cost[training_cost_xmin: num_epochs],
            color='#2A6EA6')
    ax.grid(True)
    ax.set_xlabel('Epoch')
    ax.set_title('Cost on the training data')
    plt.show()

def plot_test_accuracy(test_accuracy, num_epochs, test_accuracy_xmin):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(np.arange(test_accuracy_xmin, num_epochs),
            [accuracy/100.0
             for accuracy in test_accuracy[test_accuracy_xmin:num_epochs]],
             color = '#2A6EA6')
    ax.set_xlim([test_accuracy_xmin, num_epochs])
    ax.grid(True)
    ax.set_xlabel('Epoch')
    ax.set_title('Accuracy (%) on the test data')
    plt.show()

def plot_test_cost(test_cost, num_epochs, test_cost_xmin):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(np.arange(test_cost_xmin, num_epochs),
            test_cost[test_cost_xmin:num_epochs],
            color = '#2A6EA6')
    ax.set_xlim([test_cost_xmin, num_epochs])
    ax.grid(True)
    ax.set_xlabel('Epoch')
    ax.set_title("Cost on the test data")
    plt.show()

def plot_training_accuracy(training_accuracy, num_epochs, training_cost_xmin, training_set_size):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(np.arange(training_accuracy_xmin, num_epochs),
                      [accuracy*100.0/training_set_size
                       for accuracy in training_accuracy[training_accuracy_xmin:num_epochs]],
                       color = '#2A6EA6')
    ax.set_xlim([training_accuracy_xmin, num_epochs])
    ax.grid(True)
    ax.set_xlabel('Epoch')
    ax.set_title('Accuracy (%) on the training data')
    plt.show()

def plot_overlay(test_accuracy, training_accuracy, num_epochs, xmin, training_set_size):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(np.arange(xmin, num_epochs),
            [accuracy/100.0 for accuracy in test_accuracy],
            color = '#2A6EA6',
            label = "Accuracy on the test data")
    ax.plot(np.arange(xmin, num_epochs),
            [accuracy * 100.0 / training_set_size
             for accuracy in training_accuracy],
             color = '#FFA933',
             label = 'Accuracy on the training data')
    ax.grid(True)
    ax.set_xlim([xmin, num_epochs])
    ax.set_xlabel('Epoch')
    ax.set_ylim([90,100])
    plt.legend(loc = 'lower right')
    plt.show()

if __name__ == "__main__":
    filename = input("Enter a file name: ")
    num_epochs = int(input("Enter the number of epochs to run for: "))
    training_cost_xmin = int(input("training_cost_xmin (suggest 200): "))
    test_accuracy_xmin = int(input("test_accuracy_xmin (suggest 200): "))
    test_cost_xmin = int (input("test_cost_xmin (suggest 0): "))
    training_accuracy_xmin = int(input("training_accuracy_xmin (suggest 0): "))
    training_set_size = int(input("Training set size (suggest 1000): "))
    lmbda = float(input("Enter the regularization parameter, lambda (suggest: 5.0): "))
    main(filename, num_epochs, training_cost_xmin, test_accuracy_xmin, test_cost_xmin,training_accuracy_xmin,training_set_size, lmbda)
# Out:
# Enter a file name: overfitting_result
# Enter the number of epochs to run for: 30
# training_cost_xmin (suggest 200): 200
# test_accuracy_xmin (suggest 200): 200
# test_cost_xmin (suggest 0): 0
# training_accuracy_xmin (suggest 0): 0
# Training set size (suggest 1000): 1000
# Enter the regularization parameter, lambda (suggest: 5.0): 5
# Epoch 0 training complete
# Cost on training data: 35658.66991318522
# Accuracy on training data: 659 / 1000
# Cost on evaluation data: 35658.8785475098
# Accuracy on evaluation data: 5713 / 10000
# Epoch 1 training complete
# Cost on training data: 21765.5400837868
# Accuracy on training data: 777 / 1000
# Cost on evaluation data: 21765.81134352749
# Accuracy on evaluation data: 6879 / 10000
# Epoch 2 training complete
# Cost on training data: 13373.160249628041
# Accuracy on training data: 831 / 1000
# Cost on evaluation data: 13373.407701927135
# Accuracy on evaluation data: 7506 / 10000
# Epoch 3 training complete
# Cost on training data: 8309.095886737805
# Accuracy on training data: 896 / 1000
# Cost on evaluation data: 8309.38449825595
# Accuracy on evaluation data: 8070 / 10000
# Epoch 4 training complete
# Cost on training data: 5256.578235251615
# Accuracy on training data: 908 / 1000
# Cost on evaluation data: 5256.8706406089805
# Accuracy on evaluation data: 8232 / 10000
# Epoch 5 training complete
# Cost on training data: 3420.31034238835
# Accuracy on training data: 924 / 1000
# Cost on evaluation data: 3420.6073383556154
# Accuracy on evaluation data: 8317 / 10000
# Epoch 6 training complete
# Cost on training data: 2317.829406586262
# Accuracy on training data: 931 / 1000
# Cost on evaluation data: 2318.131180493867
# Accuracy on evaluation data: 8403 / 10000
# Epoch 7 training complete
# Cost on training data: 1651.9882412326785
# Accuracy on training data: 944 / 1000
# Cost on evaluation data: 1652.2973344731847
# Accuracy on evaluation data: 8482 / 10000
# Epoch 8 training complete
# Cost on training data: 1254.3439030722368
# Accuracy on training data: 937 / 1000
# Cost on evaluation data: 1254.6533401799907
# Accuracy on evaluation data: 8432 / 10000
# Epoch 9 training complete
# Cost on training data: 1008.041839246929
# Accuracy on training data: 948 / 1000
# Cost on evaluation data: 1008.3460646606959
# Accuracy on evaluation data: 8651 / 10000
# Epoch 10 training complete
# Cost on training data: 868.3567330670016
# Accuracy on training data: 922 / 1000
# Cost on evaluation data: 868.6878507338195
# Accuracy on evaluation data: 8303 / 10000
# Epoch 11 training complete
# Cost on training data: 781.2311972100548
# Accuracy on training data: 934 / 1000
# Cost on evaluation data: 781.542812393409
# Accuracy on evaluation data: 8418 / 10000
# Epoch 12 training complete
# Cost on training data: 730.8690190182701
# Accuracy on training data: 946 / 1000
# Cost on evaluation data: 731.1949243497111
# Accuracy on evaluation data: 8563 / 10000
# Epoch 13 training complete
# Cost on training data: 698.2425286599857
# Accuracy on training data: 953 / 1000
# Cost on evaluation data: 698.5601271287401
# Accuracy on evaluation data: 8655 / 10000
# Epoch 14 training complete
# Cost on training data: 683.2469044004239
# Accuracy on training data: 956 / 1000
# Cost on evaluation data: 683.5692334029699
# Accuracy on evaluation data: 8636 / 10000
# Epoch 15 training complete
# Cost on training data: 669.6810087936535
# Accuracy on training data: 923 / 1000
# Cost on evaluation data: 670.0205750727657
# Accuracy on evaluation data: 8227 / 10000
# Epoch 16 training complete
# Cost on training data: 659.9403599822552
# Accuracy on training data: 946 / 1000
# Cost on evaluation data: 660.2453287455701
# Accuracy on evaluation data: 8609 / 10000
# Epoch 17 training complete
# Cost on training data: 659.5365714607817
# Accuracy on training data: 951 / 1000
# Cost on evaluation data: 659.8466119740525
# Accuracy on evaluation data: 8575 / 10000
# Epoch 18 training complete
# Cost on training data: 655.9067811346837
# Accuracy on training data: 955 / 1000
# Cost on evaluation data: 656.2128034461332
# Accuracy on evaluation data: 8740 / 10000
# Epoch 19 training complete
# Cost on training data: 652.824701438632
# Accuracy on training data: 947 / 1000
# Cost on evaluation data: 653.1599594744683
# Accuracy on evaluation data: 8554 / 10000
# Epoch 20 training complete
# Cost on training data: 650.2245810873097
# Accuracy on training data: 946 / 1000
# Cost on evaluation data: 650.5535350877359
# Accuracy on evaluation data: 8653 / 10000
# Epoch 21 training complete
# Cost on training data: 648.916768263768
# Accuracy on training data: 950 / 1000
# Cost on evaluation data: 649.2589011833767
# Accuracy on evaluation data: 8576 / 10000
# Epoch 22 training complete
# Cost on training data: 650.1138466860871
# Accuracy on training data: 937 / 1000
# Cost on evaluation data: 650.4725872411387
# Accuracy on evaluation data: 8287 / 10000
# Epoch 23 training complete
# Cost on training data: 651.2253765747442
# Accuracy on training data: 942 / 1000
# Cost on evaluation data: 651.5528730020192
# Accuracy on evaluation data: 8535 / 10000
# Epoch 24 training complete
# Cost on training data: 653.1354905709887
# Accuracy on training data: 933 / 1000
# Cost on evaluation data: 653.5033350955625
# Accuracy on evaluation data: 8202 / 10000
# Epoch 25 training complete
# Cost on training data: 649.1398628982053
# Accuracy on training data: 952 / 1000
# Cost on evaluation data: 649.4682810915808
# Accuracy on evaluation data: 8665 / 10000
# Epoch 26 training complete
# Cost on training data: 646.4748108415606
# Accuracy on training data: 922 / 1000
# Cost on evaluation data: 646.8168332862828
# Accuracy on evaluation data: 8246 / 10000
# Epoch 27 training complete
# Cost on training data: 647.2914395755251
# Accuracy on training data: 954 / 1000
# Cost on evaluation data: 647.6214965016593
# Accuracy on evaluation data: 8632 / 10000
# Epoch 28 training complete
# Cost on training data: 645.275750537516
# Accuracy on training data: 946 / 1000
# Cost on evaluation data: 645.6176935325491
# Accuracy on evaluation data: 8563 / 10000
# Epoch 29 training complete
# Cost on training data: 648.2984590095147
# Accuracy on training data: 939 / 1000
# Cost on evaluation data: 648.6269495667517
# Accuracy on evaluation data: 8561 / 10000
